# %%
import csv
with open('C:\\Users\\Charandeep\\Downloads\\Competitor Analysis - Feature.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    x = ""
    for inde, row in enumerate(spamreader):
#         print(', '.join(row))
        if inde > 1 and inde < 96:
#             print(row)
            for ob in row:
                if ob == 'PTO':
                    print(ob)
                print(ob)
# Out:
# ",PTO,Time,Employee
# Shifts
# Roster,Expenses,Skills,Training
# /
# LMS,Perf
# Reviews,Bulk
# Performance
# Reviews,Goals,Checkins,Awards,Gift
# Cards,Feedback,ATS,Chrome
# Extension
# for
# LinkedIn,AI
# Based
# Scoring,Requisition
# Management,Position
# Approval
# Flows,Candidate
# Deep
# Search,Resume
# Parsing,Offer
# Letters,Onboarding,Career
# Planner,Succession
# Planning,Compensation
# Management,iOS,Android,Retention
# Management,Workforce
# Planning,Privacy
# Shield,,Covered
# Data
# by
# Privacy
# Shield,,Else?,Comments,Customer.
# Talk,Competitor's
# Advs,,,,Pricing
# Management,,
# ,BizMerlinHR,X,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,,,,,,,,,,
# ,BizNeo
# HR,X,âœ”,âœ”,X,âœ”,âœ”,âœ”,X,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,âœ”,X,âœ”,X,X,X,X,âœ”,âœ”,X,âœ”,âœ”,âœ”,âœ”,X,X,X,âœ”,âœ”,âœ”,âœ”,X,âœ”,X,X,X,X,,"1)
# App
# is
# not
# available
# on
# IOS,
# ...
